# %% [markdown]
# # Best practices in data visualization - ASPP 2023 Crete, Heraklion <a name="TOC"></a>
#
# ## Exercise 1: Mastering matplotlib
#
# ### Table of contents
#
# [0. Anatomy of a figure](#anatomy)
# [1. Single axes](#single_axes) \
# &emsp;[1.1 Data Preparation](#data_prep) \
# &emsp;[1.2 Plotting with defaults](#plot_defaults) \
# &emsp;[1.3 The two interfaces](#interfaces) \
# &emsp;[1.4 Style sheets](#style_sheets) \
# &emsp;[1.5 Customizing the plot](#customize) \
# &emsp;&emsp;[1.5.1 Default parameters](#default_params)\
# &emsp;&emsp;[1.5.2 Making custom settings](#custom_settings)\
# &emsp;[1.6 Legend](#legend) \
# &emsp;[1.7 Saving the result](#save_result) \
# [2. Multiple axes (subplots)](#multiple_axes) \
# [3. More exercises](#exercises) \
# &emsp;[3.1 Better typography](#typography)\
# &emsp;[3.2 Better style](#style)\
# &emsp;[3.3 Making a style sheet to ensure consistency](#style_sheet2)\
#
#
# ---
# In this introduction, we'll see how to make a [figure](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html?highlight=figure#matplotlib.pyplot.figure) and play with the different settings such as improving the rendering. We'll also see how to compose a figure with a  moderately complex layout and several [subplots](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html).

# %% [markdown]
# ## 0. Anatomy of a figure <a name="anatomy"></a><span style="float:right;"><a class="small" style="color:black; text-decoration: none; " href = "#TOC" name="TOC">[Back to TOC]</a></span>
# <img src="data/anatomy.png" width="50%" align="left" /> <img src="data/subplots.png" width="50%" />
#
# These images come from the [cheatsheets](https://github.com/matplotlib/cheatsheets).

# %% [markdown]
# # 1. Single axes <a name="single_axes"> </a><span style="float:right;"><a class="small" style="color:black; text-decoration: none; " href = "#TOC" name="TOC">[Back to TOC]</a></span>
#
# We'll start by playing with a very simple example (sine and cosine trigonometric functions) using the [plot](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html) function and see what options are avalaible to us.
#
# **Note** The standard way of importing maplotlib is `import matplotlib.pyplot as plt` and then use the `plt` prefix in front of matplotlib related functions. Sometimes, we also use the `matplotlib` prefix.
#
# ## 1.1 Data preparation <a name="data_prep">
#
# In this exercise, we generate our own data using the [numpy](https://numpy.org) library. With the sine and cosine functions, we generate 257 values linearly spaced between -π and +π and compute the sine and cosine of these values.

# %%
import numpy as np

X = np.linspace(-np.pi, np.pi, 257, endpoint=True)
C, S = np.cos(X), np.sin(X)

# %% [markdown]
# X is now a numpy array with 257 values ranging from -π to +π (included). C is the cosine (257 values) and S is the sine (257 values). We're ready to plot them.

# %% [markdown]
# ## 1.2 Plotting with defaults <a name ="plot_defaults">
#
# Let's draw our first figure and observe what the result looks like.

# %%
import matplotlib.pyplot as plt

plt.plot(X, C)
plt.plot(X, S)
plt.show()

# %% [markdown]
# **Discuss with partner:** What aspects of this plot could be improved?
#
# **Answer:**

# %% [markdown]
# We chose the value `257` arbitrarily. But what if we had chosen fewer points? \
# The plot is below--why does it look a bit strange? What does this mean for plotting? What if I plotted 25,700 points instead?

# %%
Xfew = np.linspace(-np.pi, np.pi, 8, endpoint=True)
Cfew, Sfew = np.cos(Xfew), np.sin(Xfew)

plt.plot(Xfew, Cfew)
plt.plot(Xfew, Sfew)
plt.show()

# %% [markdown]
# ## 1.3 The two interfaces <a name="interfaces">
#
# When dealing with figures and axes, `matplotlib` has two parallel interfaces, or styles of using the library:
#
#  - the implicit `pyplot` interface (`plt.xlabel`), whose methods are generally applied to the current axes or figure.
#  - the object-oriented interface (`ax.set_xlabel`) - uses methods on a figure or axes object to create other artists, and build a visualization step by step
#
#  It is recommended to use the object-oriented interface, as it is more flexible and usually allows for clearer code.
#
# **Exercise:** The code below was written by someone who was a little unfamiliar with how matplotlib works.
#  - Question 1. Why are the lines and labels only appearing in the second plot?
#  - Question 2. Change the code so that it uses the object-oriented interface. Does the plot now look like what you'd expect?

# %%
fig, axs = plt.subplots(2, 1, num=1, figsize=(9, 4), clear=True)

ax = axs[0]
plt.plot(X, C)
plt.plot(X, S)
plt.xlabel('Angle')
plt.ylabel('Trig (fine)')
plt.xlim([-np.pi, np.pi])

ax = axs[1]
plt.plot(Xfew, Cfew)
plt.plot(Xfew, Sfew)
plt.xlabel('Angle')
plt.ylabel('Trig (fine)')
plt.xlim([-np.pi, np.pi])
# Out:
# (-3.141592653589793, 3.141592653589793)

# %%
# solution
fig, axs = plt.subplots(2, 1, num=1, figsize=(9, 4), clear=True)

ax = axs[0]
ax.plot(X, C)
ax.plot(X, S)
ax.set_xlabel('Angle')
ax.set_ylabel('Trig (fine)')
ax.set_xlim([-np.pi, np.pi])

ax = axs[1]
ax.plot(Xfew, Cfew)
ax.plot(Xfew, Sfew)
ax.set_xlabel('Angle')
ax.set_ylabel('Trig (fine)')
ax.set_xlim([-np.pi, np.pi])
# Out:
# (-3.141592653589793, 3.141592653589793)

# %% [markdown]
# ## 1.4 Style sheets <a name="style_sheets">
#
# Sometimes, there are some plotting settings that we want to apply to all of our plots. (E.g., a new color cycle, changing the axes spines to dark grey, etc.) The easiest way to do that is to use [style sheets](https://matplotlib.org/stable/tutorials/introductory/customizing.html). Matplotlib has [several built in](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html), or you can make your own once you know which values in `plt.rcParams` you want to update.
#
# To use a style sheet for all plots in a session:
# ```python
# plt.style.use(<sheet_name>)
# ```
# If you want to use a style sheet on just a single plot without changing the default plot settings you can use a context manager:
# ```python
# with plt.style.context(<sheet_name>):
#     plt.plot(...)
# ```
#
#
# **Exercise:** Copy and paste the code from the first exercise (section 1.2. plotting with defaults). Using the `with` statement explore different [style sheets](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html).
#
# **Explore** the ones that start with 'seaborn', like **'poster'**, **'talk'**, **paper'** and **'notebook'**. What is different between them?

# %%
# solution
with plt.style.context('seaborn-poster'):
    fig, ax = plt.subplots(1, 1, num=1, figsize=(9, 4), clear=True)
    ax.plot(X, C)
    ax.plot(X, S)
    ax.set_xlabel('Angle')
    ax.set_ylabel('Trig (fine)')
    ax.set_xlim([-np.pi, np.pi])
    plt.show()
        
with plt.style.context('seaborn-paper'):
    fig, ax = plt.subplots(1, 1, num=1, figsize=(9, 4), clear=True)
    ax.plot(X, C)
    ax.plot(X, S)
    ax.set_xlabel('Angle')
    ax.set_ylabel('Trig (fine)')
    ax.set_xlim([-np.pi, np.pi])
    plt.show()

# %% [markdown]
# Asnwer: the suffix in seaborn stylesheets are made for different applications:
# - poster as in a conference poster,
# - notebook as in a jupyter notebook to showcase code
# - etc.
#
# The main difference is the font sizes and the ratio of ink. Remember the 4th rule for constructing a figure "Adapt the figure to support the medium"? \
# In a poster you need more ink as it is seen from afar. In a paper you need less

# %% [markdown]
# ## 1.5 Customizing the plot <a name="customize">
#
# As you saw in the previous section style sheets can do a lot in improving a figure, even overriding matplotlib defaults. Still, none of the style sheets can address all the plot changes we want, so we sometimes need to explicitly fine tune our settings.
#
# ### 1.5.1 Accessing default parameters  <a name="default_params">
#
# Check out the defaults from the [matplotlibrc](https://matplotlib.org/stable/tutorials/introductory/customizing.html#customizing-with-matplotlibrc-files) configuration file that is accessible through the `plt.rcParams` variable.
#
# **Exercise:** Run the following cell, then look at the keys the dictionary `p` contains.
# - What is the default font size of the title?
# - What is the default figure size?
# - What is the default linewidth

# %%
# solution cell

p = plt.rcParams

# explore...

print('the default font size is')
print(p['font.size'])


print('the default figure size is')
print(p['figure.figsize'])

print('the default line width')
print(p['lines.linewidth'])
# Out:
# the default font size is
# 10.0
# the default figure size is
# [6.0, 4.0]
# the default line width
# 1.5

# %% [markdown]
# ### 1.5.2 Making custom settings <a name="custom_settings">
#
# We can modify `plt.rcParams` to change default parameters. This will affect all the posterior figures in the session. In the example below, we modify figure size, which can be specified in inches, and the DPI (dots per inch) of the figure to get a better resolution in the notebook.

# %%
# Set default figure size 
plt.rcParams['figure.figsize'] = [6, 4]
# Set default figure dpi
plt.rcParams['figure.dpi'] = 72

plt.plot(X, C)
plt.plot(X, S)
plt.xlabel('Angle')
plt.ylabel('Trig (fine)')
plt.xlim([-np.pi, np.pi])
# Out:
# (-3.141592653589793, 3.141592653589793)

# %% [markdown]
# #### Line styles
#
# Solid line is the default line style but there exist [several other styles](https://matplotlib.org/stable/gallery/lines_bars_and_markers/linestyles.html) such as dashed lines (`linestyle="--"`), dotted lines (`linestyle=":"`), etc. You can also combine a style with a marker. For example, we can add circular markers at regular intervals. To do that, we specify the `marker` symbol as `'o'`, the marker color and the spacing between markers (else you will have a marker at each data  point).
#
# **Exercise:** Modify the code below to have circular markers every 32 data ponts. Can you change the filling color of the markers to white?

# %%
# solution - change, without markevery so that the marker appears everywhere

fig,ax = plt.subplots()
ax.plot(X, C, marker='o') #try using 'markevery='
ax.plot(X, S, marker='o') 
plt.show()

# %%
# solution

fig,ax = plt.subplots()
ax.plot(X, C, marker='o', markevery=32, markerfacecolor="white")
ax.plot(X, S, marker='o', markevery=32, markerfacecolor="white")
plt.show()

# %% [markdown]
# #### Tick positions and labels
#
# Ticks on the x axis are not ideal positioned because they do not show the interesting values (+/-$\pi$,+/-$\pi$/2) and there are too many ticks on the y axis.
#
# **Exercise:** Change the xticks so they only occur at multiples of π/2 and the yticks so they only occur at -1, 0 and 1.
#
# (Hint: The methods you are looking for are `ax.set_xticks` and `ax.set_xticklabels`, and their y-axis counterparts.)

# %%
# modify ....

fig,ax = plt.subplots()
ax.plot(X, C, marker="o", markevery=32, markerfacecolor="white")
ax.plot(X, S, marker="o", markevery=32, markerfacecolor="white")
#add ticks

plt.show()

# %%
# solution

fig,ax = plt.subplots()
ax.plot(X, C, marker="o", markevery=32, markerfacecolor="white")
ax.plot(X, S, marker="o", markevery=32, markerfacecolor="white")
ax.set_xticks([-np.pi, -np.pi/2, 0,np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2", "0","π/2", "$π$"])
ax.set_yticks([-1, 0, 1])
ax.set_yticklabels(["-1", "0", "+1"])
plt.show()

# %% [markdown]
# #### Spines position
#
# Spines are the four lines around the figure and delimiting the data area. By default, there are four spines at the top, bottom, left and right; but we can hide some of them and move the others.
#
# **Exercise:** Modify the following code so that the right and top spines are no longer visible. Change the position of the bottom and left spines so that their positions are at 0 in data coordinates. (Hint: The handles to the right spine are accessible by `ax.spines['right']`. The spine object has two relevant methods for this exercise: `set_visible` and `set_position`.)

# %%
fig,ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white")
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white")

ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2","π/2", "$π$"])
ax.set_yticks([-1,1])
ax.set_yticklabels(["-1", "+1"])

#add code here

plt.show();

# %%
#solution
fig,ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white")
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white")

ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2","π/2", "$π$"])
ax.set_yticks([-1,1])
ax.set_yticklabels(["-1", "+1"])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

plt.show();

# %% [markdown]
# #### Z order
#
# Now that our spines overlap our lines, we can see that the axes are plotted on top the lines. It was already the case previosuly but it was less noticeable. To change it, we need to tell matplotlib to render our sine and cosine plots in front of the axis. For that, we specify a [zorder](https://matplotlib.org/stable/gallery/misc/zorder_demo.html#zorder-demo), which indicate in which order the figure elements will be rendered.
#
# **Exercise:** Use the `zorder` keyword argument in `plot` to move the lines above the axes. Note that axes correspond to a zorder of 0.

# %%
fig,ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white")
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white")

ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2", "π/2", "π"])
ax.set_yticks([-1, 1])
ax.set_yticklabels(["-1",  "+1"])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

plt.show()

# %%
#solution 

fig,ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white", zorder=3) #any number bigger than 3 would work
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white", zorder=3)

ax.set_xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2", "0","π/2", "π"])
ax.set_yticks([-1, 1])
ax.set_yticklabels(["-1",  "+1"])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

plt.show()

# %% [markdown]
# ## 1.6 Legend <a name = "legend">
#
# Matplotlib allows adding legends with [a great degree of control](https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html). For now, we will add a simple legend in the upper left-hand corner. We do this by labelling the data we plot (i.e., adding the keyword argument `label` into our `plot` function) and then calling `ax.legend`.
#
# **Exercise**: Label the cosine and sine curves. Add a legend in the upper left corner, and use `frameon=False` to turn off the border around the legend.

# %%
fig,ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white", 
         zorder=10)
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white", 
          zorder=10)
    
ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2", "π/2", "π"])
ax.set_yticks([-1, 1])
ax.set_yticklabels(["-1", "+1"])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))


# Add a legend
plt.show()

# %%
#solution

fig,ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white", 
         zorder=10, label="cosine")
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white", 
          zorder=10, label="sine")
    
ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2", "π/2", "π"])
ax.set_yticks([-1, 1])
ax.set_yticklabels(["-1", "+1"])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))


# Add a legend
ax.legend(loc='upper left', frameon=False);
plt.show()

# %% [markdown]
# #### Font size and title
#
# The font size of the tick labels is a bit small. Let's increase it a bit. We can also add a title on the left of our figure.

# %%
fig,ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white",
              zorder=10, label="cosine")
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white",
              zorder=10, label="sine")

# Change ticks and labels
ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2", "π/2", "π"])
ax.set_yticks([-1, 1])
ax.set_yticklabels(["-1", "+1"])

# Change spines location and visibility
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

# Add a legend
ax.legend(loc='upper left', frameon=False);

# Add a title  

# Increase fontsize
    
plt.show()

# %%
#solution
fig,ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white",
              zorder=10, label="cosine")
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white",
              zorder=10, label="sine")

# Change ticks and labels
ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2", "π/2", "π"])
ax.set_yticks([-1, 1])
ax.set_yticklabels(["-1", "+1"])

# Change spines location and visibility
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

# Add a legend
ax.legend(loc='upper left', frameon=False);

# Add a title
ax.set_title("Trigonometric functions", x=0.1)  

# Increase fontsize
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize("large");
    
plt.show()

# %% [markdown]
# ## 1.7 Saving the result <a name = "save_result">
#
# We can now save our figure in a file. There are many different figure formats, but vector graphics will produce a figure that is flawless independently of the zoom level. So let's save to a PDF.

# %%
fig, ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white",
              zorder=10, label="cosine")
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white",
              zorder=10, label="sine")

ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2", "π/2", "π"])
ax.set_yticks([-1, 1])
ax.set_yticklabels(["-1", "+1"])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

ax.legend(loc='upper left', frameon=False);
ax.set_title("Trigonometric functions", x=0.1)  
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize("large");

# Save the result before showing it in the notebook

plt.show()

# %%
# solution
fig, ax = plt.subplots()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white",
              zorder=10, label="cosine")
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white",
              zorder=10, label="sine")

ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels(["-π", "-π/2", "π/2", "π"])
ax.set_yticks([-1, 1])
ax.set_yticklabels(["-1", "+1"])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))

ax.legend(loc='upper left', frameon=False);
ax.set_title("Trigonometric functions", x=0.1)  
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize("large");

# Save the result before showing it in the notebook
plt.savefig("data/a-nicer-plot.pdf")

plt.show()

# %% [markdown]
#
# ---
#
#
# #  2. Multiple axes <a name="multiple_axes"></a><span style="float:right;"><a class="small" style="color:black; text-decoration: none; " href = "#TOC" name="TOC">[Back to TOC]</a></span>
#
# Matplotlib offers the possibility to draw several plots on the same figure.

# %% [markdown]
# To do that we need to create two axes. The most straigthforward way is to use the `plt.subplots` method to create subplots with the specified rows and colums. This method returns an array of axes that you can index to access the axes of your choice. You can also use the `plt.subplot` method, which is similar to the Matlab `subplot` function.

# %%
nrows, ncols = 2, 3
fig, axs = plt.subplots(nrows, ncols, figsize=(12,7))
for index in range(nrows*ncols):
    ax = axs[index // ncols, index % ncols];
    ax.set_title("plt.subplot(%d,%d,%d)" % (nrows, ncols, index+1), weight="bold")
    
plt.tight_layout()
plt.show();

# %% [markdown]
# What if we want to have more complex layout with plot of unequal size? In this case, the best is to use the [gridspec](https://matplotlib.org/stable/api/_as_gen/matplotlib.gridspec.GridSpec.html) method. It also involves dividing the figure into rows and columns, but now we can specify the bounds of each plot, i.e. position and extent and their relative size. Let's see some example.

# %%
from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(10,6))
    
nrows, ncols = 2, 2
widths = 1, 2  # Experiment changing 2 to 3,4,5, etc
heights = 1, 2 # Experiment changing 2 to 3,4,5, etc
G = GridSpec(nrows, ncols, width_ratios = widths, height_ratios=heights)

aspect= 'auto' # Experiment with aspect=1
ax = plt.subplot(G[0,0], aspect=aspect); ax.plot(X,C,X,S); ax.grid(1)
ax = plt.subplot(G[1,0], aspect=aspect); ax.plot(X,C,X,S); ax.grid(1)
ax = plt.subplot(G[0,1], aspect=aspect); ax.plot(X,C,X,S); ax.grid(1)
ax = plt.subplot(G[1,1], aspect=aspect); ax.plot(X,C,X,S); ax.grid(1)

plt.show();

# %% [markdown]
# Using gridspec, you can specify any layout, the only difficulty being to be able to express what you want to achieve.

# %% [markdown]
#
# ---
#
#
# # 3. More exercises <a name="exercises"> </a><span style="float:right;"><a class="small" style="color:black; text-decoration: none; " href = "#TOC" name="TOC">[Back to TOC]</a></span>

# %% [markdown]
# ## 3.1 Better typography <a name="typography">
#
# We used π/2 to display pi over two to but it would be better to display $\frac{\pi}{2}$. How would you do modify the tick labels to obtain the same output as in the figure below?
#
# **Hint:** You can edit this notebook cell to see how I wrote $\frac{\pi}{2}$.
#
# <img src="data/01-exercise-1.png" width="100%" />

# %%
# solution
X = np.linspace(-np.pi, np.pi, 257, endpoint=True)
C, S = np.cos(X), np.sin(X)

fig = plt.figure(figsize=(8,3))
ax = plt.subplot()

ax.plot(X, C, marker="o", markevery=(0, 32), markerfacecolor="white",
        zorder=10, label="cosine")
ax.plot(X, S, marker="o", markevery=(0, 32), markerfacecolor="white",
        zorder=10, label="sine")

ax.set_xticks([-np.pi, -np.pi/2, np.pi/2, np.pi])
ax.set_xticklabels([r"$-\pi$", r"$-\frac{\pi}{2}$",
                    r"$+\frac{\pi}{2}$", r"$+\pi$"])
ax.set_yticks([-1,1])
ax.set_yticklabels([r"$-1$", r"$+1$"])

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_position(('data',0))
ax.spines['left'].set_position(('data',0))
ax.legend(loc='upper left', frameon=False);
ax.set_title("Trigonometric functions", x=0.1)

for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize("large")
    
plt.show()

# %% [markdown]
# ## 3.2 [Optional] Better style <a name="style" >
#
# Starting from the code template below, you need to write the subplot function to achieve the same result as the figure below. The tricky task is to obtain the arrows at end of x and y axis. You can plot them using specific [markers](https://matplotlib.org/stable/api/markers_api.html).
#
# <img src="data/01-exercise-2.png" width="100%" />

# %%
import numpy as np
import matplotlib.pyplot as plt
raise Exception("!!! To be completed")

def subplot_with_style(index, title):    
    # To be completed HERE
    return ax

fig = plt.figure(figsize=(13,5), dpi=300)
X = np.linspace (-4,4,200)

subplot_with_style(1, "y = cos(x)").plot(X, np.cos(X), "C1")
subplot_with_style(2, "y = sin(x)").plot(X, np.sin(X), "C1")
subplot_with_style(3, "y = tan(x)").plot(X, np.tan(X), "C1")
subplot_with_style(4, "y = cosh(x)").plot(X, np.cosh(X), "C1")
subplot_with_style(5, "y = sinh(x)").plot(X, np.sinh(X), "C1")
subplot_with_style(6, "y = tanh(x)").plot(X, np.tanh(X), "C1")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Input In [75], in <cell line: 3>()
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 raise Exception("!!! To be completed")
#       5 def subplot_with_style(index, title):
#       6     # To be completed HERE
#       7     return ax
#
# Exception: !!! To be completed

# %%
#solution
def subplot(index, title):    
    ax = plt.subplot(2, 3, index, aspect=1)
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_position(('data',0))
    ax.spines['left'].set_position(('data',0))
    ax.set_xlim(-4.5,4.5)
    ax.set_xticks([-4,-3,-2,-1,1,2,3,4])
    ax.plot(4.5, 0, ">k", clip_on=False)
    ax.set_ylim(-2.5,2.5)
    ax.set_yticks([-2,-1,1,2])
    ax.plot(0, 2.5, "^k", clip_on=False)
    ax.text(-4.5, 2, title, weight=600)
    ax.grid(linewidth=0.5, linestyle="--")
    return ax

fig = plt.figure(figsize=(10,4))
X = np.linspace (-4,4,200)

subplot(1, "y = cos(x)").plot(X, np.cos(X), "C1")
subplot(2, "y = sin(x)").plot(X, np.sin(X), "C1")
subplot(3, "y = tan(x)").plot(X, np.tan(X), "C1")
subplot(4, "y = cosh(x)").plot(X, np.cosh(X), "C1")
subplot(5, "y = sinh(x)").plot(X, np.sinh(X), "C1")
subplot(6, "y = tanh(x)").plot(X, np.tanh(X), "C1")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3.3 [Optional] Making a style sheet to ensure style consistency <a name ="style_sheet2">
#
# We've discussed using built-in style sheets and `plt.rcParams`, but we have not explored how we can generate our own style sheets. Style sheets are text files with the extension `.mplstyle` that overwrite the settings in `plt.rcParams` when loaded. Here is a partial example of a simple style sheet from [this tutorial](https://towardsdatascience.com/how-to-create-and-use-custom-matplotlib-style-sheet-9393f498063):
#
# ```
# ### FIGURE
# figure.facecolor: white
# figure.dpi: 100
# figure.titleweight: bold
#
# ### LINES
# lines.linewidth: 1.5
#
# ### LEGEND
# legend.fontsize: 12
#
# ### AXES
# axes.spines.top: True
# axes.spines.right: True
# axes.prop_cycle: cycler(
#     'color', ['0072B2', '009E73', 'D55E00', 'CC79A7', 'F0E442', '56B4E9']
# )
# ```
#
# Your exercise is to make your own style sheet. Use the `defaults` function we wrote above to explore which options are available, and save the values into a local sheet. Test the style sheet in the function below.

# %%
X = np.linspace(-np.pi, np.pi, 257, endpoint=True)
C, S = np.cos(X), np.sin(X)

with plt.style.context('seaborn-darkgrid'): # use here your stylesheet!
    plt.plot(X, C, label='cosine')
    plt.plot(X, S, label='sine')
    plt.xlabel('x')
    plt.ylabel('y')

# %% [markdown]
# ----
# This notebook is modified version from [this other one](https://github.com/ASPP/2021-bordeaux-dataviz/blob/master/01-introduction.ipynb), taught at ASPP 2021.
#
# **Copyright (c) 2021 Nicolas P. Rougier**
# This work is licensed under a [Creative Commons Attribution 4.0 International License](http://creativecommons.org/licenses/by/4.0/).
# <br/>
# Code is licensed under a [2-Clauses BSD license](https://opensource.org/licenses/BSD-2-Clause)
